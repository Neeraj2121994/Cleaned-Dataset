# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv(r"C:\Users\Neeraj Fartyal\OneDrive\Desktop\Tableau\datasets\netflix_titles.csv")

# %%
ds.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
ds.shape
# Out:
# (8807, 12)

# %%
ds.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
ds['show_id'].unique
# Out:
# <bound method Series.unique of 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 8802    s8803
# 8803    s8804
# 8804    s8805
# 8805    s8806
# 8806    s8807
# Name: show_id, Length: 8807, dtype: object>

# %%
ds=ds.drop(['description','show_id'], axis=1)

# %%
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
ds['director'].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
ds['director'].value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
ds.shape
# Out:
# (8807, 10)

# %%
ds=ds.drop_duplicates()

# %%
ds.shape
# Out:
# (8807, 10)

# %%
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds=ds.dropna(thresh=7)
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds['director']=ds['director'].fillna(method='bfill')

# %%
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water  Julien Leclercq
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans    Mike Flanagan
# 4  TV Show           Kota Factory    Mike Flanagan
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds['director'].value_counts()
# Out:
# Raúl Campos, Jan Suter              33
# Jay Karas                           28
# Marcus Raboy                        25
# Charlie Haskell, Koichi Sakamoto    20
# Suhas Kadav                         20
#                                     ..
# Adam Bhala Lough                     1
# Faozan Rizal                         1
# Mansore                              1
# Kuntz Agus                           1
# Mozez Singh                          1
# Name: director, Length: 4528, dtype: int64

# %%
ds['director'].isnull().sum()
# Out:
# 0

# %%
director=ds['director'].value_counts()
director
director_th_3=director[director<2]

# %%
director_th_3
# Out:
# Robi Michael        1
# Greg Coolidge       1
# Jenny Carchman      1
# Neil Triffett       1
# Shadi Ali           1
#                    ..
# Adam Bhala Lough    1
# Faozan Rizal        1
# Mansore             1
# Kuntz Agus          1
# Mozez Singh         1
# Name: director, Length: 2630, dtype: int64

# %%
def comdir(value):
    if value in director_th_3:
        return 'others'
    else:
        return value
ds['director']=ds['director'].apply(comdir)
ds['director'].value_counts()
# Out:
# others                              2630
# Raúl Campos, Jan Suter                33
# Jay Karas                             28
# Marcus Raboy                          25
# Charlie Haskell, Koichi Sakamoto      20
#                                     ...
# Gupse Özay                             2
# Jim Mickle                             2
# Michael J. Bassett                     2
# Scott Aukerman                         2
# Majid Al Ansari                        2
# Name: director, Length: 1899, dtype: int64

# %%
ds['cast'].value_counts()
# Out:
# David Attenborough                                                                                                                                                                            19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                       14
# Samuel West                                                                                                                                                                                   10
# Jeff Dunham                                                                                                                                                                                    7
# David Spade, London Hughes, Fortune Feimster                                                                                                                                                   6
# ...

# %%
ds['cast'].isnull().sum()
# Out:
# 825

# %%
ds.head(10)
# Out:
#       type                             title         director  \
# 0    Movie              Dick Johnson Is Dead           others
# 1  TV Show                     Blood & Water  Julien Leclercq
# 2  TV Show                         Ganglands  Julien Leclercq
# 3  TV Show             Jailbirds New Orleans    Mike Flanagan
# 4  TV Show                      Kota Factory    Mike Flanagan
# 5  TV Show                     Midnight Mass    Mike Flanagan
# 6    Movie  My Little Pony: A New Generation           others
# 7    Movie                           Sankofa           others
# 8  TV Show     The Great British Baking Show           others
# 9    Movie                      The Starling           others
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# ...

# %%
ds['cast'].unique()
# Out:
# array([nan,
#        'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng',
#        'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera',
#        ...,
#        'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf',
#        'Tim Allen, Courteney Cox, Chevy Chase, Kate Mara, Ryan Newman, Michael Cassidy, Spencer Breslin, Rip Torn, Kevin Zegers',
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy'],
#       dtype=object)

# %%
ds['cast']=ds['cast'].fillna(method='bfill')
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead           others
# 1  TV Show          Blood & Water  Julien Leclercq
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans    Mike Flanagan
# 4  TV Show           Kota Factory    Mike Flanagan
#
#                                                 cast        country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds.head(15)
# Out:
#        type                                title  \
# 0     Movie                 Dick Johnson Is Dead
# 1   TV Show                        Blood & Water
# 2   TV Show                            Ganglands
# 3   TV Show                Jailbirds New Orleans
# 4   TV Show                         Kota Factory
# 5   TV Show                        Midnight Mass
# 6     Movie     My Little Pony: A New Generation
# 7     Movie                              Sankofa
# 8   TV Show        The Great British Baking Show
# 9     Movie                         The Starling
# 10  TV Show  Vendetta: Truth, Lies and The Mafia
# 11  TV Show                     Bangkok Breaking
# 12    Movie                         Je Suis Karl
# 13    Movie     Confessions of an Invisible Girl
# 14  TV Show      Crime Stories: India Detectives
#
#                                          director  \
# 0                                          others
# 1                                 Julien Leclercq
# ...

# %%
ds.isnull().sum()
# Out:
# type              0
# title             0
# director          0
# cast              0
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# dtype: int64

# %%
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead           others
# 1  TV Show          Blood & Water  Julien Leclercq
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans    Mike Flanagan
# 4  TV Show           Kota Factory    Mike Flanagan
#
#                                                 cast        country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds['cast'].value_counts()
# Out:
# David Attenborough                                                                                                                                                                                                      21
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                                                 14
# Samuel West                                                                                                                                                                                                             10
# Iliza Shlesinger                                                                                                                                                                                                         9
# ...

# %%
cast=ds['cast'].value_counts()
cast_lt_2=cast[cast<2]
cast_lt_2
# Out:
# Adam Sandler, Kathy Bates, Henry Winkler, Fairuza Balk, Jerry Reed, Lawrence Gilliard Jr., Blake Clark, Peter Dante, Jonathan Loughran, Al Whiting                                                                      1
# Michael Sinterniklaas, Michaela Dean, Doug Erholtz, Braeden Fox, Olivia Hack, David Lodge, Nayo Wallace, Ryan Wiesbrock                                                                                                 1
# Hannibal Buress                                                                                                                                                                                                         1
# Reid Scott, John Eric Bentley, Amir Talai, Phil LaMarr, Grey DeLisle, Michael Patrick Bell, Eric Bauza                                                                                                                  1
# ...

# %%
def castcom(value):
    if value in cast_lt_2:
        return 'others'
    else:
        return value
ds['cast']=ds['cast'].apply(castcom)
ds['cast'].value_counts()
# Out:
# others                                                                                                                                                                                  6852
# David Attenborough                                                                                                                                                                        21
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                   14
# Samuel West                                                                                                                                                                               10
# Iliza Shlesinger                                                                                                                                                                           9
# ...

# %%
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead           others
# 1  TV Show          Blood & Water  Julien Leclercq
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans    Mike Flanagan
# 4  TV Show           Kota Factory    Mike Flanagan
#
#                                                 cast        country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2                                             others            NaN
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds['country'].isnull().sum()
# Out:
# 831

# %%
ds.shape
# Out:
# (8807, 10)

# %%
ds['country'].value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
ds['country']=ds['country'].fillna(ds['country'].mode()[0])

# %%
ds
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead           others
# 1     TV Show          Blood & Water  Julien Leclercq
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans    Mike Flanagan
# 4     TV Show           Kota Factory    Mike Flanagan
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb  Ruben Fleischer
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom           others
# 8806    Movie                 Zubaan           others
#
#                                                    cast        country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2                                                others  United States
# ...

# %%
ds['country'].value_counts()
# Out:
# United States                             3649
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
country=ds['country'].value_counts()
country_lt_2=country[country<2]
country_lt_2
# Out:
# Pakistan, Norway, United States                   1
# France, Germany, Switzerland                      1
# United States, United Kingdom, Denmark, Sweden    1
# United States, Canada, Belgium, United Kingdom    1
# Germany, United States, Hong Kong, Singapore      1
#                                                  ..
# Romania, Bulgaria, Hungary                        1
# Uruguay, Guatemala                                1
# France, Senegal, Belgium                          1
# Mexico, United States, Spain, Colombia            1
# United Arab Emirates, Jordan                      1
# Name: country, Length: 563, dtype: int64

# %%
def countrycom(value):
    if value in country_lt_2:
        return 'others'
    else:
        return value
ds['country']=ds['country'].apply(countrycom)
ds['country'].value_counts()
# Out:
# United States                             3649
# India                                      972
# others                                     563
# United Kingdom                             419
# Japan                                      245
#                                           ...
# Australia, United Kingdom                    2
# Canada, South Africa                         2
# Canada, Australia                            2
# United States, United Kingdom, Germany       2
# New Zealand, United States                   2
# Name: country, Length: 186, dtype: int64

# %%
ds.isnull().sum()
# Out:
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# dtype: int64

# %%
ds.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead           others
# 1  TV Show          Blood & Water  Julien Leclercq
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans    Mike Flanagan
# 4  TV Show           Kota Factory    Mike Flanagan
#
#                                                 cast        country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2                                             others  United States
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
ds
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead           others
# 1     TV Show          Blood & Water  Julien Leclercq
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans    Mike Flanagan
# 4     TV Show           Kota Factory    Mike Flanagan
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb  Ruben Fleischer
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom           others
# 8806    Movie                 Zubaan           others
#
#                                                    cast        country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2                                                others  United States
# ...

# %%
ds.dropna(subset=['date_added'], inplace=True)

# %%
ds.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          4
# duration        3
# listed_in       0
# dtype: int64

# %%
ds.drop(['duration'], axis=1, inplace=True)

# %%
ds
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead           others
# 1     TV Show          Blood & Water  Julien Leclercq
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans    Mike Flanagan
# 4     TV Show           Kota Factory    Mike Flanagan
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb  Ruben Fleischer
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom           others
# 8806    Movie                 Zubaan           others
#
#                                                    cast        country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2                                                others  United States
# ...

# %%
ds.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          4
# listed_in       0
# dtype: int64

# %%
ds['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
ds['rating'].value_counts()
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
ds['rating']=ds['rating'].fillna(ds['rating'].mode()[0])

# %%
ds.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# listed_in       0
# dtype: int64

# %%
ds.to_excel('Netflix_cleaned_data.xlsx')
